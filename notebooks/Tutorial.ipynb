# %%
import sys
import os
notebook_dir = os.path.dirname(os.path.abspath('.'))
parent_dir = os.path.abspath(os.path.join(notebook_dir, '..'))
sys.path.insert(0, parent_dir)
from model.run import search_gene_expression

# %%
#check your gene
search_gene_expression('SSTR2')
# Out:
# Gene: SSTR2
# Not detected in: appendix, breast, caudate, cerebellum, cerebral cortex, cervix, colon, endometrium 1, endometrium 2, heart muscle, hippocampus, kidney, liver, lung, lymph node, ovary, pancreas, prostate, skeletal muscle, smooth muscle, soft tissue 1, spleen, tonsil
# High expression in: cerebellum
# Medium expression in: adipose tissue, adrenal gland, appendix, bronchus, cerebellum, cerebral cortex, colon, duodenum, endometrium 2, epididymis, esophagus, gallbladder, kidney, liver, lung, oral mucosa, ovary, pancreas, parathyroid gland, placenta, rectum, salivary gland, seminal vesicle, skin 1, skin 2, small intestine, soft tissue 1, soft tissue 2, stomach 1, stomach 2, testis, tonsil, urinary bladder
# Low expression in: breast, cerebral cortex, cervix, endometrium 1, fallopian tube, nasopharynx, soft tissue 2, thyroid gland, vagina
